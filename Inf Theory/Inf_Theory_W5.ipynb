# %% [markdown]
# # Assignment 4
#
# # BDA-1902 Kassymkhan, Zhanat

# %%
import pandas as pd
import numpy as np
import sys
import re
import os

# %% [markdown]
# ## Task 1

# %%
with open('new_text.txt', 'r') as file:
    encoded_text = file.read()

# %%
print("The encoded text: ",encoded_text)
# Out:
# The encoded text:  

# %% [markdown]
# ## Task 2

# %%
decoded_text = ""
start_pos = 0

with open('text.txt', 'r') as file:
    original_text = file.read() 
counter = 1
print(f'Step {counter}.')
for i in range(len(str)):
    my_list = []
    index = -1
    k = 0
    for j in huffmanCode.keys():
        k += 1
        if huffmanCode[j][:((i+1)-start_pos)] == str[start_pos:(i+1)]:
            my_list.append(j)
            if index == -1:
                index = k
            
    if len(my_list) == 1:
        counter += 1
        print(f'{str[start_pos:i+1]}: Node{index}: ({str[start_pos:i+1]})', ', '.join(my_list))
        print(f'Symbol: {str[start_pos:i+1]} - {my_list[0]}\n')
        print(f'Step {counter}.')
        decoded_text += my_list[0]
        start_pos = i + 1
    else:
        print(f'{str[start_pos:i+1]}: Node{index}: ({str[start_pos:i+1]})', ', '.join(my_list))
# Out:
# Step 1.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 100: Node16: (100) B, P, D, A, s
# 1000: Node16: (1000) B, P, D, A
# 10000: Node16: (10000) B
# Symbol: 10000 - B
#
# Step 2.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 111: Node25: (111) t, C, u, n
# 1110: Node25: (1110) t, C, u
# 11101: Node26: (11101) C, u
# 111011: Node27: (111011) u
# Symbol: 111011 - u
#
# Step 3.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 100: Node16: (100) B, P, D, A, s
# 1001: Node20: (1001) s
# Symbol: 1001 - s
#
# Step 4.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 010: Node6: (010) a, i
# 0101: Node7: (0101) i
# Symbol: 0101 - i
#
# Step 5.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 111: Node25: (111) t, C, u, n
# 1111: Node28: (1111) n
# Symbol: 1111 - n
#
# Step 6.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 001: Node5: (001) e
# Symbol: 001 - e
#
# Step 7.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 100: Node16: (100) B, P, D, A, s
# 1001: Node20: (1001) s
# Symbol: 1001 - s
#
# Step 8.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 100: Node16: (100) B, P, D, A, s
# 1001: Node20: (1001) s
# Symbol: 1001 - s
#
# Step 9.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 101: Node21: (101)
# Symbol: 101 -
#
# Step 10.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 100: Node16: (100) B, P, D, A, s
# 1000: Node16: (1000) B, P, D, A
# 10001: Node17: (10001) P, D, A
# 100010: Node17: (100010) P
# Symbol: 100010 - P
#
# Step 11.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 100: Node16: (100) B, P, D, A, s
# 1000: Node16: (1000) B, P, D, A
# 10001: Node17: (10001) P, D, A
# 100011: Node18: (100011) D, A
# 1000111: Node19: (1000111) A
# Symbol: 1000111 - A
#
# Step 12.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 111: Node25: (111) t, C, u, n
# 1110: Node25: (1110) t, C, u
# 11101: Node26: (11101) C, u
# 111010: Node26: (111010) C
# Symbol: 111010 - C
#
# Step 13.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 101: Node21: (101)
# Symbol: 101 -
#
# Step 14.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 100: Node16: (100) B, P, D, A, s
# 1000: Node16: (1000) B, P, D, A
# 10001: Node17: (10001) P, D, A
# 100011: Node18: (100011) D, A
# 1000110: Node18: (1000110) D
# Symbol: 1000110 - D
#
# Step 15.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 110: Node22: (110) l, d, o
# 1101: Node24: (1101) o
# Symbol: 1101 - o
#
# Step 16.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 111: Node25: (111) t, C, u, n
# 1111: Node28: (1111) n
# Symbol: 1111 - n
#
# Step 17.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 010: Node6: (010) a, i
# 0100: Node6: (0100) a
# Symbol: 0100 - a
#
# Step 18.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 111: Node25: (111) t, C, u, n
# 1110: Node25: (1110) t, C, u
# 11100: Node25: (11100) t
# Symbol: 11100 - t
#
# Step 19.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 010: Node6: (010) a, i
# 0101: Node7: (0101) i
# Symbol: 0101 - i
#
# Step 20.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 110: Node22: (110) l, d, o
# 1101: Node24: (1101) o
# Symbol: 1101 - o
#
# Step 21.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 111: Node25: (111) t, C, u, n
# 1111: Node28: (1111) n
# Symbol: 1111 - n
#
# Step 22.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 100: Node16: (100) B, P, D, A, s
# 1001: Node20: (1001) s
# Symbol: 1001 - s
#
# Step 23.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 101: Node21: (101)
# Symbol: 101 -
#
# Step 24.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 000: Node1: (000) R, T, h, p
# 0000: Node1: (0000) R, T
# 00001: Node2: (00001) T
# Symbol: 00001 - T
#
# Step 25.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 010: Node6: (010) a, i
# 0100: Node6: (0100) a
# Symbol: 0100 - a
#
# Step 26.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 111: Node25: (111) t, C, u, n
# 1111: Node28: (1111) n
# Symbol: 1111 - n
#
# Step 27.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 011: Node8: (011) V, g, r, :, b, k, W, c
# 0111: Node12: (0111) b, k, W, c
# 01110: Node12: (01110) b, k
# 011101: Node13: (011101) k
# Symbol: 011101 - k
#
# Step 28.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 001: Node5: (001) e
# Symbol: 001 - e
#
# Step 29.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 110: Node22: (110) l, d, o
# 1100: Node22: (1100) l, d
# 11001: Node23: (11001) d
# Symbol: 11001 - d
#
# Step 30.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 101: Node21: (101)
# Symbol: 101 -
#
# Step 31.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 000: Node1: (000) R, T, h, p
# 0000: Node1: (0000) R, T
# 00001: Node2: (00001) T
# Symbol: 00001 - T
#
# Step 32.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 110: Node22: (110) l, d, o
# 1101: Node24: (1101) o
# Symbol: 1101 - o
#
# Step 33.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 101: Node21: (101)
# Symbol: 101 -
#
# Step 34.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 000: Node1: (000) R, T, h, p
# 0000: Node1: (0000) R, T
# 00000: Node1: (00000) R
# Symbol: 00000 - R
#
# Step 35.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 001: Node5: (001) e
# Symbol: 001 - e
#
# Step 36.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 000: Node1: (000) R, T, h, p
# 0001: Node3: (0001) h, p
# 00011: Node4: (00011) p
# Symbol: 00011 - p
#
# Step 37.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 111: Node25: (111) t, C, u, n
# 1110: Node25: (1110) t, C, u
# 11101: Node26: (11101) C, u
# 111011: Node27: (111011) u
# Symbol: 111011 - u
#
# Step 38.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 011: Node8: (011) V, g, r, :, b, k, W, c
# 0111: Node12: (0111) b, k, W, c
# 01110: Node12: (01110) b, k
# 011100: Node12: (011100) b
# Symbol: 011100 - b
#
# Step 39.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 110: Node22: (110) l, d, o
# 1100: Node22: (1100) l, d
# 11000: Node22: (11000) l
# Symbol: 11000 - l
#
# Step 40.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 010: Node6: (010) a, i
# 0101: Node7: (0101) i
# Symbol: 0101 - i
#
# Step 41.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 011: Node8: (011) V, g, r, :, b, k, W, c
# 0111: Node12: (0111) b, k, W, c
# 01111: Node14: (01111) W, c
# 011111: Node15: (011111) c
# Symbol: 011111 - c
#
# Step 42.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 010: Node6: (010) a, i
# 0100: Node6: (0100) a
# Symbol: 0100 - a
#
# Step 43.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 111: Node25: (111) t, C, u, n
# 1111: Node28: (1111) n
# Symbol: 1111 - n
#
# Step 44.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 100: Node16: (100) B, P, D, A, s
# 1001: Node20: (1001) s
# Symbol: 1001 - s
#
# Step 45.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 101: Node21: (101)
# Symbol: 101 -
#
# Step 46.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 011: Node8: (011) V, g, r, :, b, k, W, c
# 0111: Node12: (0111) b, k, W, c
# 01111: Node14: (01111) W, c
# 011110: Node14: (011110) W
# Symbol: 011110 - W
#
# Step 47.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 000: Node1: (000) R, T, h, p
# 0001: Node3: (0001) h, p
# 00010: Node3: (00010) h
# Symbol: 00010 - h
#
# Step 48.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 110: Node22: (110) l, d, o
# 1101: Node24: (1101) o
# Symbol: 1101 - o
#
# Step 49.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 101: Node21: (101)
# Symbol: 101 -
#
# Step 50.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 111: Node25: (111) t, C, u, n
# 1110: Node25: (1110) t, C, u
# 11101: Node26: (11101) C, u
# 111010: Node26: (111010) C
# Symbol: 111010 - C
#
# Step 51.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 000: Node1: (000) R, T, h, p
# 0001: Node3: (0001) h, p
# 00010: Node3: (00010) h
# Symbol: 00010 - h
#
# Step 52.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 010: Node6: (010) a, i
# 0100: Node6: (0100) a
# Symbol: 0100 - a
#
# Step 53.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 110: Node22: (110) l, d, o
# 1100: Node22: (1100) l, d
# 11000: Node22: (11000) l
# Symbol: 11000 - l
#
# Step 54.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 110: Node22: (110) l, d, o
# 1100: Node22: (1100) l, d
# 11000: Node22: (11000) l
# Symbol: 11000 - l
#
# Step 55.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 001: Node5: (001) e
# Symbol: 001 - e
#
# Step 56.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 111: Node25: (111) t, C, u, n
# 1111: Node28: (1111) n
# Symbol: 1111 - n
#
# Step 57.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 011: Node8: (011) V, g, r, :, b, k, W, c
# 0110: Node8: (0110) V, g, r, :
# 01100: Node8: (01100) V, g
# 011001: Node9: (011001) g
# Symbol: 011001 - g
#
# Step 58.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 001: Node5: (001) e
# Symbol: 001 - e
#
# Step 59.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 110: Node22: (110) l, d, o
# 1100: Node22: (1100) l, d
# 11001: Node23: (11001) d
# Symbol: 11001 - d
#
# Step 60.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 101: Node21: (101)
# Symbol: 101 -
#
# Step 61.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 100: Node16: (100) B, P, D, A, s
# 1000: Node16: (1000) B, P, D, A
# 10000: Node16: (10000) B
# Symbol: 10000 - B
#
# Step 62.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 010: Node6: (010) a, i
# 0101: Node7: (0101) i
# Symbol: 0101 - i
#
# Step 63.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 110: Node22: (110) l, d, o
# 1100: Node22: (1100) l, d
# 11001: Node23: (11001) d
# Symbol: 11001 - d
#
# Step 64.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 001: Node5: (001) e
# Symbol: 001 - e
#
# Step 65.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 111: Node25: (111) t, C, u, n
# 1111: Node28: (1111) n
# Symbol: 1111 - n
#
# Step 66.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 101: Node21: (101)
# Symbol: 101 -
#
# Step 67.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 011: Node8: (011) V, g, r, :, b, k, W, c
# 0110: Node8: (0110) V, g, r, :
# 01100: Node8: (01100) V, g
# 011000: Node8: (011000) V
# Symbol: 011000 - V
#
# Step 68.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 110: Node22: (110) l, d, o
# 1101: Node24: (1101) o
# Symbol: 1101 - o
#
# Step 69.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 111: Node25: (111) t, C, u, n
# 1110: Node25: (1110) t, C, u
# 11100: Node25: (11100) t
# Symbol: 11100 - t
#
# Step 70.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 001: Node5: (001) e
# Symbol: 001 - e
#
# Step 71.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 011: Node8: (011) V, g, r, :, b, k, W, c
# 0110: Node8: (0110) V, g, r, :
# 01101: Node10: (01101) r, :
# 011011: Node11: (011011) :
# Symbol: 011011 - :
#
# Step 72.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 10: Node16: (10) B, P, D, A, s,
# 101: Node21: (101)
# Symbol: 101 -
#
# Step 73.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 000: Node1: (000) R, T, h, p
# 0000: Node1: (0000) R, T
# 00000: Node1: (00000) R
# Symbol: 00000 - R
#
# Step 74.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 001: Node5: (001) e
# Symbol: 001 - e
#
# Step 75.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 00: Node1: (00) R, T, h, p, e
# 000: Node1: (000) R, T, h, p
# 0001: Node3: (0001) h, p
# 00011: Node4: (00011) p
# Symbol: 00011 - p
#
# Step 76.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 110: Node22: (110) l, d, o
# 1101: Node24: (1101) o
# Symbol: 1101 - o
#
# Step 77.
# 0: Node1: (0) R, T, h, p, e, a, i, V, g, r, :, b, k, W, c
# 01: Node6: (01) a, i, V, g, r, :, b, k, W, c
# 011: Node8: (011) V, g, r, :, b, k, W, c
# 0110: Node8: (0110) V, g, r, :
# 01101: Node10: (01101) r, :
# 011010: Node10: (011010) r
# Symbol: 011010 - r
#
# Step 78.
# 1: Node16: (1) B, P, D, A, s,  , l, d, o, t, C, u, n
# 11: Node22: (11) l, d, o, t, C, u, n
# 111: Node25: (111) t, C, u, n
# 1110: Node25: (1110) t, C, u
# 11100: Node25: (11100) t
# Symbol: 11100 - t
#
# Step 79.

# %% [markdown]
# ## Task 3

# %%
print("Decoded text: " ,decoded_text)
print("Original text: ",original_text)

if original_text == decoded_text:
    print("The original text and decoded text match.")
else:
    print("Error occured")
# Out:
# Decoded text:  Business PAC Donations Tanked To Republicans Who Challenged Biden Vote: Report
# Original text:  Business PAC Donations Tanked To Republicans Who Challenged Biden Vote: Report
# The original text and decoded text match.
