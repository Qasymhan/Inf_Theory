# %% [markdown]
# # Assignment 4
#
# # BDA-1902 Kassymkhan, Zhanat

# %%
import pandas as pd
import numpy as np
import sys
import re
import os

# %% [markdown]
# ## Task 1

# %%
with open('new_text.txt', 'r') as file:
    encoded_text = file.read()

# %%
print("The encoded text: ",encoded_text)
# Out:
# The encoded text:  

# %% [markdown]
# ## Task 2

# %%
decoded_text = ""
start_pos = 0

with open('text.txt', 'r') as file:
    original_text = file.read() 

for i in range(len(str)):
    my_list = []
    for j in huffmanCode.keys():
        if huffmanCode[j][:((i+1)-start_pos)] == str[start_pos:(i+1)]:
            my_list.append(j)
    if len(my_list) == 1:
        print(f'Symbol: {str[start_pos:i+1]} - {my_list}\n')
        decoded_text += my_list[0]
        start_pos = i + 1
    else:
        print(f'{str[start_pos:i+1]} - {my_list}')
# Out:
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# 100 - ['B', 'P', 'D', 'A', 's']
# 1000 - ['B', 'P', 'D', 'A']
# Symbol: 10000 - ['B']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 111 - ['t', 'C', 'u', 'n']
# 1110 - ['t', 'C', 'u']
# 11101 - ['C', 'u']
# Symbol: 111011 - ['u']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# 100 - ['B', 'P', 'D', 'A', 's']
# Symbol: 1001 - ['s']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 010 - ['a', 'i']
# Symbol: 0101 - ['i']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 111 - ['t', 'C', 'u', 'n']
# Symbol: 1111 - ['n']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# Symbol: 001 - ['e']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# 100 - ['B', 'P', 'D', 'A', 's']
# Symbol: 1001 - ['s']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# 100 - ['B', 'P', 'D', 'A', 's']
# Symbol: 1001 - ['s']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# Symbol: 101 - [' ']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# 100 - ['B', 'P', 'D', 'A', 's']
# 1000 - ['B', 'P', 'D', 'A']
# 10001 - ['P', 'D', 'A']
# Symbol: 100010 - ['P']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# 100 - ['B', 'P', 'D', 'A', 's']
# 1000 - ['B', 'P', 'D', 'A']
# 10001 - ['P', 'D', 'A']
# 100011 - ['D', 'A']
# Symbol: 1000111 - ['A']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 111 - ['t', 'C', 'u', 'n']
# 1110 - ['t', 'C', 'u']
# 11101 - ['C', 'u']
# Symbol: 111010 - ['C']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# Symbol: 101 - [' ']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# 100 - ['B', 'P', 'D', 'A', 's']
# 1000 - ['B', 'P', 'D', 'A']
# 10001 - ['P', 'D', 'A']
# 100011 - ['D', 'A']
# Symbol: 1000110 - ['D']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 110 - ['l', 'd', 'o']
# Symbol: 1101 - ['o']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 111 - ['t', 'C', 'u', 'n']
# Symbol: 1111 - ['n']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 010 - ['a', 'i']
# Symbol: 0100 - ['a']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 111 - ['t', 'C', 'u', 'n']
# 1110 - ['t', 'C', 'u']
# Symbol: 11100 - ['t']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 010 - ['a', 'i']
# Symbol: 0101 - ['i']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 110 - ['l', 'd', 'o']
# Symbol: 1101 - ['o']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 111 - ['t', 'C', 'u', 'n']
# Symbol: 1111 - ['n']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# 100 - ['B', 'P', 'D', 'A', 's']
# Symbol: 1001 - ['s']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# Symbol: 101 - [' ']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# 000 - ['R', 'T', 'h', 'p']
# 0000 - ['R', 'T']
# Symbol: 00001 - ['T']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 010 - ['a', 'i']
# Symbol: 0100 - ['a']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 111 - ['t', 'C', 'u', 'n']
# Symbol: 1111 - ['n']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 011 - ['V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 0111 - ['b', 'k', 'W', 'c']
# 01110 - ['b', 'k']
# Symbol: 011101 - ['k']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# Symbol: 001 - ['e']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 110 - ['l', 'd', 'o']
# 1100 - ['l', 'd']
# Symbol: 11001 - ['d']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# Symbol: 101 - [' ']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# 000 - ['R', 'T', 'h', 'p']
# 0000 - ['R', 'T']
# Symbol: 00001 - ['T']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 110 - ['l', 'd', 'o']
# Symbol: 1101 - ['o']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# Symbol: 101 - [' ']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# 000 - ['R', 'T', 'h', 'p']
# 0000 - ['R', 'T']
# Symbol: 00000 - ['R']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# Symbol: 001 - ['e']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# 000 - ['R', 'T', 'h', 'p']
# 0001 - ['h', 'p']
# Symbol: 00011 - ['p']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 111 - ['t', 'C', 'u', 'n']
# 1110 - ['t', 'C', 'u']
# 11101 - ['C', 'u']
# Symbol: 111011 - ['u']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 011 - ['V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 0111 - ['b', 'k', 'W', 'c']
# 01110 - ['b', 'k']
# Symbol: 011100 - ['b']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 110 - ['l', 'd', 'o']
# 1100 - ['l', 'd']
# Symbol: 11000 - ['l']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 010 - ['a', 'i']
# Symbol: 0101 - ['i']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 011 - ['V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 0111 - ['b', 'k', 'W', 'c']
# 01111 - ['W', 'c']
# Symbol: 011111 - ['c']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 010 - ['a', 'i']
# Symbol: 0100 - ['a']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 111 - ['t', 'C', 'u', 'n']
# Symbol: 1111 - ['n']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# 100 - ['B', 'P', 'D', 'A', 's']
# Symbol: 1001 - ['s']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# Symbol: 101 - [' ']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 011 - ['V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 0111 - ['b', 'k', 'W', 'c']
# 01111 - ['W', 'c']
# Symbol: 011110 - ['W']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# 000 - ['R', 'T', 'h', 'p']
# 0001 - ['h', 'p']
# Symbol: 00010 - ['h']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 110 - ['l', 'd', 'o']
# Symbol: 1101 - ['o']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# Symbol: 101 - [' ']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 111 - ['t', 'C', 'u', 'n']
# 1110 - ['t', 'C', 'u']
# 11101 - ['C', 'u']
# Symbol: 111010 - ['C']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# 000 - ['R', 'T', 'h', 'p']
# 0001 - ['h', 'p']
# Symbol: 00010 - ['h']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 010 - ['a', 'i']
# Symbol: 0100 - ['a']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 110 - ['l', 'd', 'o']
# 1100 - ['l', 'd']
# Symbol: 11000 - ['l']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 110 - ['l', 'd', 'o']
# 1100 - ['l', 'd']
# Symbol: 11000 - ['l']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# Symbol: 001 - ['e']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 111 - ['t', 'C', 'u', 'n']
# Symbol: 1111 - ['n']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 011 - ['V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 0110 - ['V', 'g', 'r', ':']
# 01100 - ['V', 'g']
# Symbol: 011001 - ['g']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# Symbol: 001 - ['e']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 110 - ['l', 'd', 'o']
# 1100 - ['l', 'd']
# Symbol: 11001 - ['d']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# Symbol: 101 - [' ']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# 100 - ['B', 'P', 'D', 'A', 's']
# 1000 - ['B', 'P', 'D', 'A']
# Symbol: 10000 - ['B']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 010 - ['a', 'i']
# Symbol: 0101 - ['i']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 110 - ['l', 'd', 'o']
# 1100 - ['l', 'd']
# Symbol: 11001 - ['d']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# Symbol: 001 - ['e']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 111 - ['t', 'C', 'u', 'n']
# Symbol: 1111 - ['n']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# Symbol: 101 - [' ']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 011 - ['V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 0110 - ['V', 'g', 'r', ':']
# 01100 - ['V', 'g']
# Symbol: 011000 - ['V']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 110 - ['l', 'd', 'o']
# Symbol: 1101 - ['o']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 111 - ['t', 'C', 'u', 'n']
# 1110 - ['t', 'C', 'u']
# Symbol: 11100 - ['t']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# Symbol: 001 - ['e']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 011 - ['V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 0110 - ['V', 'g', 'r', ':']
# 01101 - ['r', ':']
# Symbol: 011011 - [':']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 10 - ['B', 'P', 'D', 'A', 's', ' ']
# Symbol: 101 - [' ']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# 000 - ['R', 'T', 'h', 'p']
# 0000 - ['R', 'T']
# Symbol: 00000 - ['R']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# Symbol: 001 - ['e']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 00 - ['R', 'T', 'h', 'p', 'e']
# 000 - ['R', 'T', 'h', 'p']
# 0001 - ['h', 'p']
# Symbol: 00011 - ['p']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 110 - ['l', 'd', 'o']
# Symbol: 1101 - ['o']
#
# 0 - ['R', 'T', 'h', 'p', 'e', 'a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 01 - ['a', 'i', 'V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 011 - ['V', 'g', 'r', ':', 'b', 'k', 'W', 'c']
# 0110 - ['V', 'g', 'r', ':']
# 01101 - ['r', ':']
# Symbol: 011010 - ['r']
#
# 1 - ['B', 'P', 'D', 'A', 's', ' ', 'l', 'd', 'o', 't', 'C', 'u', 'n']
# 11 - ['l', 'd', 'o', 't', 'C', 'u', 'n']
# 111 - ['t', 'C', 'u', 'n']
# 1110 - ['t', 'C', 'u']
# Symbol: 11100 - ['t']

# %% [markdown]
# ## Task 3

# %%
print("Decoded text: " ,decoded_text)
print("Original text: ",original_text)

if original_text == decoded_text:
    print("The original text and decoded text match.")
else:
    print("Error occured")
# Out:
# Decoded text:  Business PAC Donations Tanked To Republicans Who Challenged Biden Vote: Report
# Original text:  Business PAC Donations Tanked To Republicans Who Challenged Biden Vote: Report
# The original text and decoded text match.
